# %% [markdown]
# # Ejecución desde VS Code en Google Colab Cloud Runtime
#
# ## 1. Instala las extensiones (sólo si lo quieres ejecutar desde vscode)
#
# En Visual Studio Code:
#
# 1. Abre **Extensions**.
# 2. Busca **Google Colab**.
# 3. Instala la extensión oficial de Google.
# 4. Instala también **Jupyter** si VS Code lo solicita.
#
# ---
#
# ## 2. Abre tu proyecto en VS Code (sólo si lo quieres ejecutar desde vscode)
#
# Abre la carpeta donde tienes tu proyecto:
#
# ```text
# File > Open Folder
# ```
#
# Abre este notebook en vscode o súbelo a tu carpeta de Google Colab:
#
# [Google Colab](https://colab.research.google.com/drive/)
#
# ```text
# notebook.ipynb
# ```
# ---
#
# ## 3. Selecciona un kernel de Colab (sólo si lo quieres ejecutar desde vscode)
#
# En el notebook abierto en VS Code:
#
# Pulsa Select Kernel arriba a la derecha.
# Elige Colab.
# Inicia sesión con tu cuenta de Google.
# Selecciona el runtime deseado:
# CPU
# GPU
# TPU (si está disponible)
#
# Desde ese momento, las celdas que ejecutes en VS Code se ejecutarán en el entorno cloud de Google Colab. Pasa al punto número 4.
#
# # Ejecución desde Google Colab
#
# ## 1. Abre tu Google Colab
#
# [Google Colab](https://colab.research.google.com/)
#
# ## 2. Sube este archivo
#
# Pulsa en "Archivo" --> "Subir"
#
# Pasa al punto número 4.

# %% [markdown]
# # Preparación de datos y ejecución del Proyecto
#
# ## 4. Clona el repositorio
#
# Se clona el repositorio aeat-crypto-reporter desde GitHub. Antes se borra el contenido anterior.

# %%
# !rm -rf /content/prejubilacion/
# !cd /content/ && git clone https://github.com/mrg321/prejubilacion.git
# Out:
# Cloning into 'prejubilacion'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (168/168), done.157/168)
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 168 (delta 92), reused 77 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (168/168), 195.27 KiB | 3.49 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %% [markdown]
# ## 5. Añade /app al Path

# %%
import sys
sys.path.append('./app')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython', './app']

# %% [markdown]
# ## 6. Monta Google Drive para cargar los ficheros de datos necesarios

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 7. Copia los ficheros de datos necesarios
#
# Copia los ficheros de entrada desde tu ruta de Google Drive a la ruta correspondiente del proyecto.
# En este ejemplo has creado con anterioridad la carpeta data_colab en tu Google Drive y dentro de esta carpeta tienes las carpetas inputs y outputs. data_colab/inputs tiene que tener el pdf de tus bases de cotización exportadas.
# La explicación de cómo obtener el pdf con las Bases de Cotización y cómo rellenar el fichero .env está en el archivo [readme.md](https://github.com/mrg321/prejubilacion/blob/main/README.md)
# En GitHub también tienes ejemplos de ficheros .env para:
# - [Telefónica España Dentro de Convenio] (https://github.com/mrg321/prejubilacion/blob/main/env.example.tde.dc.txt)
# - [Telefónica España Fuera de Convenio] (https://github.com/mrg321/prejubilacion/blob/main/env.example.tde.fc.txt)
# - [Telefónica Global Solutions] (https://github.com/mrg321/prejubilacion/blob/main/env.example.tgs.txt)

# %%
# !cp /content/drive/MyDrive/data_colab/inputs/*.pdf /content/prejubilacion/data/inputs/
# !cp /content/drive/MyDrive/data_colab/.env /content/prejubilacion/

# %%
# !ls -la /content/prejubilacion/data/inputs
# !ls -la /content/prejubilacion/.env
# Out:
# total 92
# drwxr-xr-x 2 root root  4096 May 17 13:34  .
# drwxr-xr-x 4 root root  4096 May 17 13:34  ..
# -rw-r--r-- 1 root root     0 May 17 13:34  gitkeep.txt
# -rw------- 1 root root 84853 May 17 13:34 'Informe Bases Cotización Online.pdf'
# -rw------- 1 root root 820 May 17 13:34 /content/prejubilacion/.env

# %% [markdown]
# ## 8. Instala las dependencias

# %%
# !pip install -r /content/prejubilacion/requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/prejubilacion/requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/prejubilacion/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from -r /content/prejubilacion/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (from -r /content/prejubilacion/requirements.txt (line 4)) (3.1.5)
# Collecting pymupdf (from -r /content/prejubilacion/requirements.txt (line 5))
#   Downloading pymupdf-1.27.2.3-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/prejubilacion/requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/prejubilacion/requirements.txt (line 1)) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->-r /content/prejubilacion/requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl->-r /content/prejubilacion/requirements.txt (line 4)) (2.0.0)
# Downloading pymupdf-1.27.2.3-cp310-abi3-manylinux_2_28_x86_64.whl (25.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 66.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.27.2.3

# %% [markdown]
# ## 9. Ejecuta el proyecto y comprueba los resultados

# %%
# !cd /content/prejubilacion/ && python app/main.py
# Out:
# [AVISO] No existe data/inputs/bases_cotizacion_ok.txt. Iniciando búsqueda de fuentes...
# [INFO] Buscando TXT intermedio en data/inputs/Informe Bases Cotizacion Online.txt...
# [INFO] No hay TXT. Buscando CSV bruto en data/inputs/Libro1.csv...
# [INFO] No hay CSV bruto. Buscando PDF en data/inputs/Informe Bases Cotizaci*n Online.pdf...
# [AVISO] No hay TXT ni CSV bruto. Generando TXT desde PDF: data/inputs/Informe Bases Cotizaci*n Online.pdf...
# [OK] TXT generado desde PDF.
# [OK] Bases generadas desde TXT: data/inputs/bases_cotizacion.txt
# [OK] Datos cargados en el sistema (filas: 43)
#
# [1] CARGA DE DATOS
#  -> Leyendo ficheros de bases, máximas, incrementos y reducciones...
#  -> Bases: 43 filas
#  -> Años con base máxima disponibles: 1990-2040 (51 años)
#  -> Bases: 43 filas
#  -> Incrementos BR: 12 filas
#  -> Tabla reducciones involuntaria: 48 filas
#  -> tabla reducciones voluntaria: 24 filas
#  -> Años con base máxima disponibles: 1990-2040 (51 años)
#  -> Años con base mínima disponibles: 1990-2040 (51 años)
#
# [2] PREPARACIÓN DE BASES Y CÓMPUTO DE MESES/AÑOS COTIZADOS
#  -> Transformando bases anchas a formato mensual...
#  ! Aviso: valor no numérico 'Sin base registrada' en Mayo-1998 → se sustituye por BASE MÍNIMA 477.09 €
#  ! Aviso: valor no numérico 'Sin base registrada' en Junio-1988 → se sustituye por BASE MÍNIMA 350.66 €
#  -> Última base real: 2026-03-01 (base=5101.20 €)
#  -> Chequeo 'últimas 12 CONOCIDAS a máxima': SÍ (evaluados=12, a_máxima=12, umbral=12)
#
# [2.A] PROYECCIÓN PRE-BAJA (hasta el mes anterior a la baja)
#  -> Añadidos meses pre-baja: 0
#
# [2.B] PERÍODO DE PRESTACIÓN POR DESEMPLEO (opcional)
#  -> SEPE activado: base=4972.34 €, meses=24
#
# [2.C] CONVENIO ESPECIAL (hasta la fecha de jubilación anticipada)
#  -> Meses a base máxima (5 años previos a baja): 60 -> ELEGIBLE
#  -> Meses CE añadidos (2028-03-01 a 2032-06-01): 52
#  * Ejemplo primer CE: 2028-03-01 -> 5432.90 €
#  * Elegibilidad base máxima: Sí
#
# [2.X] RESUMEN BASES
#  -> Meses cotizados (histórico+proyección): 525
#  -> Años cotizados reales en la anticipada: 43.75
#
# [2.5] PREPARACIÓN DE BASES PARA EL LIBRO UNIFICADO
#  -> Pestaña 'Bases_Proyectadas'
#
# [3] EDAD ORDINARIA Y ADELANTO (CÁLCULO EXACTO)
#  -> Meses cotizados acumulados a los 65: 525 (43.75 años)
#  -> Fecha ordinaria determinada: 2034-06-30 (65 años (ya alcanzaba 38,5 años))
#  -> Meses de adelanto: 24 (máx 48 por involuntaria)
#
# [4] BASE REGULADORA
#  -> Buscando configuración del año de acceso...
#  -> Período: 328, Nº mejores: 314, Divisor: 366.33
#  -> BR (mejores 314/366.33): 4492.55 €
#  -> BR (últimos 300/350): 4511.15 €
#  -> BR seleccionada: 4511.15 €
#
# [4.1] REDUCCIÓN POR COTIZACIÓN (<37 años)
#
# [4.2] PENSIÓN MÁXIMA ESTIMADA EN EL AÑO DE JUBILACIÓN
#
# [5] REDUCCIONES POR ADELANTO (según cotizados reales en la anticipada)
#
# [6] TOPE DE PENSIÓN MÁXIMA REDUCIDA
#
# [X] COMPLEMENTO BRECHA DE GÉNERO
#  -> Año: 2032, Hijos: 2, Sexo: HOMBRE
#  -> Importe mensual total: 83.10 €
#
# [7] RESULTADO FINAL Y RESUMEN
#  BR Inicial: 4511.15 €
#  Reducción por Cotización: 0.00 %
#  Reducción por Adelanto: 13.00 %
#  Tope Máxima Reducida (est. 2032): 3656.79 €
#  Pensión bruta mensual (opción 2): 3656.79 €
#  Pensión bruta mensual con Brecha (opción 2): 3739.89 €
#
# [7.5] EXPORTACIÓN LIBRO UNIFICADO
#  -> Generando Excel en: 'data/outputs/Resumen_Calculo_Jubilacion.xlsx'
#  -> Libro unificado exportado correctamente.
# Resumen jubilación: {'BR Inicial': np.float64(4511.15), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4511.15), 'Reducción por Adelanto (%)': 13.0, 'BR tras Adelanto': np.float64(3924.7), 'Porcentaje de reducción': 4.0, 'Tope Máxima Reducida (est. año jubilación)': 3656.79, 'Pensión Bruta Mensual': 3656.79, 'Años Cotizados (anticipada)': 43.75, 'Meses Adelanto': 24, 'Ruta Excel (unificado)': 'data/outputs/Resumen_Calculo_Jubilacion.xlsx', 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 83.1, 'Pensión Bruta Mensual (opción 2)': 3739.89}
# [0.1] Modalidad: ERE | SEPE: Sí | Exención 180k: Sí | Exención rentas irreg.: Sí
#
# [0] RENTAS HASTA 65 - Preparación
# [1] Leyendo tablas auxiliares de PRESTACIÓN (Min/Max y Duración)
# [2] Ajustando inicio de prestación y base reguladora (media 6 meses)
# [4] Mínimos y máximos mensuales por número de hijos
# [5] Construyendo calendario de PRESTACIÓN (+comp. SS 4,70%)
# [5] Construyendo calendario de prestación POR MESES (70%/60%) + compensación SS (4,70%)
# [6] Posprestación hasta 63 (mes 63 prorrateado: 1..(día-1))
# [7] 63–65 con prorrateos (mes 63 incluye el día; mes 65 renta 1..(día-1), pensión completa)
# [8] Preparando resúmenes
# [10] Exportando libro: data/outputs/Resumen_Rentas.xlsx
# Resumen rentas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 104590.39, 'Total renta 63-65': 84211.2, 'Total 63-65': 188801.59, 'Total baja→65': 643802.5, 'Ruta Excel (rentas)': 'data/outputs/Resumen_Rentas.xlsx', 'Ultima_pension': np.float64(4438.61), 'mes_idx': 101}
# [EXENCIÓN] Salario reg. anual (EF): 121,691.41 €
# [EXENCIÓN] Indemnización legal conjunta: 243,382.82 €
# [EXENCIÓN] Tope absoluto aplicado por sede: 180,000.00 € (sede=ESTATAL)
# [EXENCIÓN] IMPORTE EXENTO: 180,000.00 € | Meses con exención: 36
# [IRREGULAR] anios_servicio=26.857534, ejercicios_cobro=9, cociente=2.984170, aplica=True
# [IRREGULAR] Reducción total aplicada (30%): 96,423.79 €
# Resumen exención fiscal: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# [Cargar datos] Esperanza de vida cargada desde 'app/static/esperanza_vida.txt', 27 registros.
# [Cargar datos] Estimación IPC cargada desde 'app/static/tabla_IPC.txt', 81 registros.
# [Proyección pensión] Sexo: HOMBRE, Fecha jubilación ordinaria: 2034-06-30, Fecha nacimiento: 1969-06-30, Edad ordinaria: 65.00 años, Esperanza vida: 82.58 años, Meses a proyectar: 211, Pensión bruta mensual (12 pagas): 4438.61 EUR
# [Proyección pensión] IPC estimado por año: {1970: 0.068, 1971: 0.08199999999999999, 1972: 0.083, 1973: 0.114, 1974: 0.157, 1975: 0.16899999999999998, 1976: 0.17600000000000002, 1977: 0.245, 1978: 0.19699999999999998, 1979: 0.157, 1980: 0.156, 1981: 0.146, 1982: 0.14400000000000002, 1983: 0.122, 1984: 0.113, 1985: 0.08800000000000001, 1986: 0.08800000000000001, 1987: 0.052000000000000005, 1988: 0.048, 1989: 0.068, 1990: 0.067, 1991: 0.059000000000000004, 1992: 0.059000000000000004, 1993: 0.046, 1994: 0.047, 1995: 0.047, 1996: 0.036000000000000004, 1997: 0.02, 1998: 0.018000000000000002, 1999: 0.023, 2000: 0.034, 2001: 0.036000000000000004, 2002: 0.035, 2003: 0.03, 2004: 0.03, 2005: 0.034, 2006: 0.035, 2007: 0.027999999999999997, 2008: 0.040999999999999995, 2009: -0.003, 2010: 0.018000000000000002, 2011: 0.032, 2012: 0.024, 2013: 0.013999999999999999, 2014: -0.002, 2015: -0.005, 2016: -0.002, 2017: 0.02, 2018: 0.017, 2019: 0.006999999999999999, 2020: -0.003, 2021: 0.031, 2022: 0.084, 2023: 0.035, 2024: 0.032, 2025: 0.024, 2026: 0.021, 2027: 0.019, 2028: 0.02, 2029: 0.02, 2030: 0.02, 2031: 0.02, 2032: 0.02, 2033: 0.02, 2034: 0.02, 2035: 0.02, 2036: 0.02, 2037: 0.02, 2038: 0.02, 2039: 0.02, 2040: 0.02, 2041: 0.02, 2042: 0.02, 2043: 0.02, 2044: 0.02, 2045: 0.02, 2046: 0.02, 2047: 0.02, 2048: 0.02, 2049: 0.02, 2050: 0.02}
# [Proyección pensión] Nivel inicial anual (12 pagas) en 2034-07-01: 4438.61 EUR
# [Proyección pensión] Total renta proyectada: 1118489.96 EUR sobre 211 meses.
# [Proyección completa] Única opción proyectada.
# [Exportar Excel] Actualizando 'data/outputs/Resumen_Rentas.xlsx' con resultados de la proyección.
# [Exportar Excel] Apending entradas: [('Pension_Largo_Plazo_Entradas', 'sexo', 'HOMBRE'), ('Pension_Largo_Plazo_Entradas', 'fecha_ordinaria', '2034-06-30'), ('Pension_Largo_Plazo_Entradas', 'pension_base_12_opc1', 4438.61), ('Pension_Largo_Plazo_Entradas', 'fuente_esperanza_vida', 'df_ev (en memoria)'), ('Pension_Largo_Plazo_Entradas', 'fuente_ipc', 'df_ipc (en memoria)')]
# [Exportar Excel] Apending valores usados: [('Pension_Largo_Plazo_Valores_Usados', 'esperanza_vida_anios', 82.58), ('Pension_Largo_Plazo_Valores_Usados', 'meses_proyectados_opc1', 211), ('Pension_Largo_Plazo_Valores_Usados', 'metodo_revalorizacion', 'IPC anual discreto (enero)')]
# [Exportar Excel] Apending salidas: [('Pension_Largo_Plazo_Salidas', 'total_pension_desde_65', 1118489.96), ('Pension_63_65', 'total_pension_63_65', 104590.39), ('Pension_Total_63_Enadelante', 'total_pension_63_enadelante', 1223080.3499999999)]
# [Exportar Excel] Detalle_Rentas actualizado con 211 filas de la opción proyectada.
# Resumen proyección pensiones:  {'total_pension_65_enadelante': 1118489.96, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 104590.39, 'total_pension': 1223080.3499999999}
# --- Iteración 1: fecha_jub_anticipada = 2032-06-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4511.15), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4511.15), 'Reducción por Adelanto (%)': 13.0, 'BR tras Adelanto': np.float64(3924.7), 'Porcentaje de reducción': 4.0, 'Tope Máxima Reducida (est. año jubilación)': 3656.79, 'Pensión Bruta Mensual': 3656.79, 'Años Cotizados (anticipada)': 43.75, 'Meses Adelanto': 24, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3656.79}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha     base
# 524 1988-01-01    11.40
# 523 1988-02-01    11.40
# 522 1988-03-01    11.40
# 521 1988-04-01    11.40
# 520 1988-05-01    11.40
# ..         ...      ...
# 4   2032-02-01  6162.41
# 3   2032-03-01  6162.41
# 2   2032-04-01  6162.41
# 1   2032-05-01  6162.41
# 0   2032-06-01  6162.41
#
# [525 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3656.79, 'fecha_jubilacion_anticipada': datetime.datetime(2032, 6, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 104590.39, 'Total renta 63-65': 84211.2, 'Total 63-65': 188801.59, 'Total baja→65': 643802.5, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4438.61), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4438.61, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 104590.39}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1118489.96, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 104590.39, 'total_pension': 1223080.3499999999}
# --- Iteración 2: fecha_jub_anticipada = 2032-07-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4510.94), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4510.94), 'Reducción por Adelanto (%)': 12.46, 'BR tras Adelanto': np.float64(3948.87), 'Porcentaje de reducción': 4.0, 'Tope Máxima Reducida (est. año jubilación)': 3656.79, 'Pensión Bruta Mensual': 3656.79, 'Años Cotizados (anticipada)': 43.83, 'Meses Adelanto': 23, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3656.79}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha     base
# 525 1988-01-01    11.40
# 524 1988-02-01    11.40
# 523 1988-03-01    11.40
# 522 1988-04-01    11.40
# 521 1988-05-01    11.40
# ..         ...      ...
# 4   2032-03-01  6162.41
# 3   2032-04-01  6162.41
# 2   2032-05-01  6162.41
# 1   2032-06-01  6162.41
# 0   2032-07-01     0.00
#
# [526 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3656.79, 'fecha_jubilacion_anticipada': datetime.datetime(2032, 7, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 100457.16, 'Total renta 63-65': 84211.2, 'Total 63-65': 184668.36, 'Total baja→65': 639669.27, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4438.61), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4438.61, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 100457.16}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1118489.96, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 100457.16, 'total_pension': 1218947.1199999999}
# --- Iteración 3: fecha_jub_anticipada = 2032-08-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4510.72), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4510.72), 'Reducción por Adelanto (%)': 11.92, 'BR tras Adelanto': np.float64(3973.05), 'Porcentaje de reducción': 4.0, 'Tope Máxima Reducida (est. año jubilación)': 3656.79, 'Pensión Bruta Mensual': 3656.79, 'Años Cotizados (anticipada)': 43.92, 'Meses Adelanto': 22, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3656.79}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha     base
# 526 1988-01-01    11.40
# 525 1988-02-01    11.40
# 524 1988-03-01    11.40
# 523 1988-04-01    11.40
# 522 1988-05-01    11.40
# ..         ...      ...
# 4   2032-04-01  6162.41
# 3   2032-05-01  6162.41
# 2   2032-06-01  6162.41
# 1   2032-07-01     0.00
# 0   2032-08-01     0.00
#
# [527 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3656.79, 'fecha_jubilacion_anticipada': datetime.datetime(2032, 8, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 96190.9, 'Total renta 63-65': 84211.2, 'Total 63-65': 180402.1, 'Total baja→65': 635403.01, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4438.61), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4438.61, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 96190.9}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1118489.96, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 96190.9, 'total_pension': 1214680.8599999999}
# --- Iteración 4: fecha_jub_anticipada = 2032-09-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4510.48), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4510.48), 'Reducción por Adelanto (%)': 11.38, 'BR tras Adelanto': np.float64(3997.19), 'Porcentaje de reducción': 3.5, 'Tope Máxima Reducida (est. año jubilación)': 3675.84, 'Pensión Bruta Mensual': 3675.84, 'Años Cotizados (anticipada)': 44.0, 'Meses Adelanto': 21, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3675.84}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha     base
# 527 1988-01-01    11.40
# 526 1988-02-01    11.40
# 525 1988-03-01    11.40
# 524 1988-04-01    11.40
# 523 1988-05-01    11.40
# ..         ...      ...
# 4   2032-05-01  6162.41
# 3   2032-06-01  6162.41
# 2   2032-07-01     0.00
# 1   2032-08-01     0.00
# 0   2032-09-01     0.00
#
# [528 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3675.84, 'fecha_jubilacion_anticipada': datetime.datetime(2032, 9, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 92269.77, 'Total renta 63-65': 84211.2, 'Total 63-65': 176481.03, 'Total baja→65': 631481.94, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4461.73), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4461.73, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 92269.77}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1124315.9, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 92269.77, 'total_pension': 1216585.67}
# --- Iteración 5: fecha_jub_anticipada = 2032-10-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4510.24), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4510.24), 'Reducción por Adelanto (%)': 10.0, 'BR tras Adelanto': np.float64(4059.22), 'Porcentaje de reducción': 3.5, 'Tope Máxima Reducida (est. año jubilación)': 3675.84, 'Pensión Bruta Mensual': 3675.84, 'Años Cotizados (anticipada)': 44.08, 'Meses Adelanto': 20, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3675.84}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha     base
# 528 1988-01-01    11.40
# 527 1988-02-01    11.40
# 526 1988-03-01    11.40
# 525 1988-04-01    11.40
# 524 1988-05-01    11.40
# ..         ...      ...
# 4   2032-06-01  6162.41
# 3   2032-07-01     0.00
# 2   2032-08-01     0.00
# 1   2032-09-01     0.00
# 0   2032-10-01     0.00
#
# [529 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3675.84, 'fecha_jubilacion_anticipada': datetime.datetime(2032, 10, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 88115.02, 'Total renta 63-65': 84211.2, 'Total 63-65': 172326.28, 'Total baja→65': 627327.19, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4461.73), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4461.73, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 88115.02}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1124315.9, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 88115.02, 'total_pension': 1212430.92}
# --- Iteración 6: fecha_jub_anticipada = 2032-11-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4510.0), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4510.0), 'Reducción por Adelanto (%)': 8.89, 'BR tras Adelanto': np.float64(4109.06), 'Porcentaje de reducción': 3.5, 'Tope Máxima Reducida (est. año jubilación)': 3675.84, 'Pensión Bruta Mensual': 3675.84, 'Años Cotizados (anticipada)': 44.17, 'Meses Adelanto': 19, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3675.84}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha  base
# 529 1988-01-01  11.4
# 528 1988-02-01  11.4
# 527 1988-03-01  11.4
# 526 1988-04-01  11.4
# 525 1988-05-01  11.4
# ..         ...   ...
# 4   2032-07-01   0.0
# 3   2032-08-01   0.0
# 2   2032-09-01   0.0
# 1   2032-10-01   0.0
# 0   2032-11-01   0.0
#
# [530 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3675.84, 'fecha_jubilacion_anticipada': datetime.datetime(2032, 11, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 83692.81, 'Total renta 63-65': 84211.2, 'Total 63-65': 167904.07, 'Total baja→65': 622904.98, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4461.73), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4461.73, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 83692.81}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1124315.9, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 83692.81, 'total_pension': 1208008.71}
# --- Iteración 7: fecha_jub_anticipada = 2032-12-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4509.76), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4509.76), 'Reducción por Adelanto (%)': 8.0, 'BR tras Adelanto': np.float64(4148.98), 'Porcentaje de reducción': 3.0, 'Tope Máxima Reducida (est. año jubilación)': 3694.89, 'Pensión Bruta Mensual': 3694.89, 'Años Cotizados (anticipada)': 44.25, 'Meses Adelanto': 18, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3694.89}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha  base
# 530 1988-01-01  11.4
# 529 1988-02-01  11.4
# 528 1988-03-01  11.4
# 527 1988-04-01  11.4
# 526 1988-05-01  11.4
# ..         ...   ...
# 4   2032-08-01   0.0
# 3   2032-09-01   0.0
# 2   2032-10-01   0.0
# 1   2032-11-01   0.0
# 0   2032-12-01   0.0
#
# [531 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3694.89, 'fecha_jubilacion_anticipada': datetime.datetime(2032, 12, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 79950.31, 'Total renta 63-65': 84211.2, 'Total 63-65': 164161.51, 'Total baja→65': 619162.42, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4484.86), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4484.86, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 79950.31}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1130144.67, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 79950.31, 'total_pension': 1210094.98}
# --- Iteración 8: fecha_jub_anticipada = 2033-01-30 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4594.49), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4594.49), 'Reducción por Adelanto (%)': 7.27, 'BR tras Adelanto': np.float64(4260.47), 'Porcentaje de reducción': 3.0, 'Tope Máxima Reducida (est. año jubilación)': 3773.04, 'Pensión Bruta Mensual': 3773.04, 'Años Cotizados (anticipada)': 44.33, 'Meses Adelanto': 17, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3773.04}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha  base
# 531 1988-01-01  11.4
# 530 1988-02-01  11.4
# 529 1988-03-01  11.4
# 528 1988-04-01  11.4
# 527 1988-05-01  11.4
# ..         ...   ...
# 4   2032-09-01   0.0
# 3   2032-10-01   0.0
# 2   2032-11-01   0.0
# 1   2032-12-01   0.0
# 0   2033-01-01   0.0
#
# [532 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3773.04, 'fecha_jubilacion_anticipada': datetime.datetime(2033, 1, 30, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 77157.11, 'Total renta 63-65': 84211.2, 'Total 63-65': 161368.31, 'Total baja→65': 616369.22, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4579.72), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4579.72, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 77157.11}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1154048.45, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 77157.11, 'total_pension': 1231205.56}
# --- Iteración 9: fecha_jub_anticipada = 2033-02-28 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4594.24), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4594.24), 'Reducción por Adelanto (%)': 6.67, 'BR tras Adelanto': np.float64(4287.8), 'Porcentaje de reducción': 3.0, 'Tope Máxima Reducida (est. año jubilación)': 3773.04, 'Pensión Bruta Mensual': 3773.04, 'Años Cotizados (anticipada)': 44.42, 'Meses Adelanto': 16, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3773.04}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha  base
# 532 1988-01-01  11.4
# 531 1988-02-01  11.4
# 530 1988-03-01  11.4
# 529 1988-04-01  11.4
# 528 1988-05-01  11.4
# ..         ...   ...
# 4   2032-10-01   0.0
# 3   2032-11-01   0.0
# 2   2032-12-01   0.0
# 1   2033-01-01   0.0
# 0   2033-02-01   0.0
#
# [533 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3773.04, 'fecha_jubilacion_anticipada': datetime.datetime(2033, 2, 28, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# ...
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4773.01, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 19262.5}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1202755.94, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 19262.5, 'total_pension': 1222018.44}
# --- Iteración 22: fecha_jub_anticipada = 2034-03-28 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4681.93), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4681.93), 'Reducción por Adelanto (%)': 1.5, 'BR tras Adelanto': np.float64(4611.7), 'Porcentaje de reducción': 0.5, 'Tope Máxima Reducida (est. año jubilación)': 3952.15, 'Pensión Bruta Mensual': 3952.15, 'Años Cotizados (anticipada)': 45.5, 'Meses Adelanto': 3, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3952.15}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha  base
# 545 1988-01-01  11.4
# 544 1988-02-01  11.4
# 543 1988-03-01  11.4
# 542 1988-04-01  11.4
# 541 1988-05-01  11.4
# ..         ...   ...
# 4   2033-11-01   0.0
# 3   2033-12-01   0.0
# 2   2034-01-01   0.0
# 1   2034-02-01   0.0
# 0   2034-03-01   0.0
#
# [546 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3952.15, 'fecha_jubilacion_anticipada': datetime.datetime(2034, 3, 28, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 15010.34, 'Total renta 63-65': 84211.2, 'Total 63-65': 99221.54, 'Total baja→65': 554222.45, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4797.12), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4797.12, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 15010.34}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1208831.46, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 15010.34, 'total_pension': 1223841.8}
# --- Iteración 23: fecha_jub_anticipada = 2034-04-28 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4681.73), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4681.73), 'Reducción por Adelanto (%)': 1.0, 'BR tras Adelanto': np.float64(4634.92), 'Porcentaje de reducción': 0.5, 'Tope Máxima Reducida (est. año jubilación)': 3952.15, 'Pensión Bruta Mensual': 3952.15, 'Años Cotizados (anticipada)': 45.58, 'Meses Adelanto': 2, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3952.15}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha  base
# 546 1988-01-01  11.4
# 545 1988-02-01  11.4
# 544 1988-03-01  11.4
# 543 1988-04-01  11.4
# 542 1988-05-01  11.4
# ..         ...   ...
# 4   2033-12-01   0.0
# 3   2034-01-01   0.0
# 2   2034-02-01   0.0
# 1   2034-03-01   0.0
# 0   2034-04-01   0.0
#
# [547 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3952.15, 'fecha_jubilacion_anticipada': datetime.datetime(2034, 4, 28, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 10073.95, 'Total renta 63-65': 84211.2, 'Total 63-65': 94285.15, 'Total baja→65': 549286.06, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4797.12), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4797.12, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 10073.95}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1208831.46, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 10073.95, 'total_pension': 1218905.41}
# --- Iteración 24: fecha_jub_anticipada = 2034-05-28 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
# Jubilación anticipada - Salidas: {'BR Inicial': np.float64(4681.27), 'Reducción por Cotización (%)': 0.0, 'BR tras Cotización': np.float64(4681.27), 'Reducción por Adelanto (%)': 0.5, 'BR tras Adelanto': np.float64(4657.86), 'Porcentaje de reducción': 0.5, 'Tope Máxima Reducida (est. año jubilación)': 3952.15, 'Pensión Bruta Mensual': 3952.15, 'Años Cotizados (anticipada)': 45.67, 'Meses Adelanto': 1, 'Ruta Excel (unificado)': None, 'Fecha ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'Brecha género': 0.0, 'Pensión Bruta Mensual (opción 2)': 3952.15}
# Ejecutando calcular_rentas_hasta_65...
# Rentas - Entradas: {'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'fecha_baja': datetime.datetime(2026, 3, 1, 0, 0), 'modalidad': 'ERE', 'df_bases_mensuales':          fecha  base
# 547 1988-01-01  11.4
# 546 1988-02-01  11.4
# 545 1988-03-01  11.4
# 544 1988-04-01  11.4
# 543 1988-05-01  11.4
# ..         ...   ...
# 4   2034-01-01   0.0
# 3   2034-02-01   0.0
# 2   2034-03-01   0.0
# 1   2034-04-01   0.0
# 0   2034-05-01   0.0
#
# [548 rows x 2 columns], 'pension_bruta_mensual_14pagas': 3952.15, 'fecha_jubilacion_anticipada': datetime.datetime(2034, 5, 28, 0, 0), 'fecha_jubilacion_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'salario_fijo_anual': 86985.52, 'bonus_target_anual': 17397.1, 'incentivos_comerciales': 0.0, 'incentivos': 0.0, 'retribucion_tiempo': 0.0, 'gratificacion': 0.0, 'otros_conceptos': 0.0, 'complementos': 0.0, 'pct_renta_hasta_63': 0.68, 'pct_renta_hasta_65': 0.38, 'pct_reval_desde_63': 0.01, 'num_hijos': 2, 'export_excel': False, 'export_excel_path': None, 'incluir_tablas_entrada_en_libro': False, 'verbose': False}
# Rentas - Salidas: {'Modalidad': 'ERE', 'Prestacion_SEPE_Activa': True, 'Aplica_Exencion_Despido_180k': True, 'Aplica_Exencion_Rentas_Irregulares': True, 'Salario Regulador (anual)': 104382.62, 'Base Paro Mensual (media 6 meses)': 5014.62, 'Días prestación': 720, 'Prestación total (hasta agotar)': 37800.0, 'Complemento total durante prestación': 104160.48, 'Compensación SS empresa total': 5656.56, 'Compensación SS empresa hasta 63': 5656.56, 'Aportación CESS total': 82360.09, 'Aportación CESS hasta 63': 80721.79, 'Aportación CESS 63-65': 1638.3, 'Prestación hasta 63': 37800.0, 'Complemento durante prestación hasta 63': 104160.48, 'Renta posprestación hasta 63': 307383.87, 'Total hasta 63': 455000.91, 'Total pensión 63-65 (12 pagas)': 5416.1, 'Total renta 63-65': 84211.2, 'Total 63-65': 89627.3, 'Total baja→65': 544628.21, 'Ruta Excel (rentas)': None, 'Ultima_pension': np.float64(4797.12), 'mes_idx': 101}
# Ejecutando calcular_exencion_fiscal...
# Exención fiscal - Salidas: {'importe_exento': 180000.0, 'num_meses_exencion': 36, 'importe_reduccion_irregular_total': 96423.79, 'desglose_indemnizacion_legal': {'salario_mensual': 10140.950833333334, 'salario_diario': 333.4011232876712, 'dias_pre': 4673.0, 'dias_post': 5130.0, 'importe_pre_45': 192080.15, 'importe_post_33': 51302.67, 'importe_legal_conjunto': 243382.82}, 'valores_usados': {'salario_reg_exencion_anual': 121691.41, 'anios_servicio': 26.857534, 'ejercicios_cobro': 9, 'cociente_antiguedad_sobre_ejercicios': 2.98417, 'aplica_reduccion_irregular': True}, 'notas_legales': 'Cálculo de indemnización exenta conforme a ET y Reforma 2012 (45 días/año hasta 12/02/2012 con tope 42 mensualidades; si inferior a 24 mensualidades, se añade 33 días/año desde 13/02/2012 hasta 24 mensualidades). Exención fiscal hasta el límite legal obligatorio y tope absoluto general de 180.000 € (art. 7.e) LIRPF). La exención no aplica a SEPE ni a Pensión. Además, si el cociente antigüedad/ejercicios fiscales es > 2, se aplica la reducción del 30% (art. 18.2 LIRPF) con tope anual de 300.000 € sobre la base reducible.'}
# Ejecutando proyectar_una_opcion...
# Proyección pensiones - Entradas: {'sexo': 'HOMBRE', 'fecha_jub_ordinaria': datetime.datetime(2034, 6, 30, 0, 0), 'fecha_nacimiento': datetime.datetime(1969, 6, 30, 0, 0), 'pension_opc1_mensual_12': 4797.12, 'export_excel': False, 'export_excel_path': None, 'mes_idx': 101, 'verbose': False, 'total_pension_63_65': 5416.1}
# Proyección pensiones - Salidas: {'total_pension_65_enadelante': 1208831.46, 'esperanza_vida_anios': 82.58, 'total_pension_63_65': 5416.1, 'total_pension': 1214247.56}
# --- Iteración 25: fecha_jub_anticipada = 2034-06-28 ---
# Iniciando cálculos...
# Ejecutando calcular_jubilacion_anticipada...
#
#     --- INFORME DE OPTIMIZACIÓN DE JUBILACIÓN ---
#
#     Se ha identificado que el valor máximo de beneficio acumulado se alcanza en la siguiente configuración:
#
#     - Fecha de Jubilación Óptima: 30/01/2033
#     - Meses de Adelanto sobre la edad ordinaria: 17 meses.
#     - Pensión Bruta Mensual (última): 4579.72 €
#     - Total Percibido (63-65 años): 77157.11 €
#     - Total Proyectado (65+ hasta esperanza vida): 1154048.45 €
#     - PENSION TOTAL ACUMULADA: 1231205.56 €
#     - Porcentaje de Reducción Aplicado: 3.00%
#     - Esperanza de Vida Asumida: 82.58 años
#
#     JUSTIFICACIÓN DEL RESULTADO:
#     El valor obtenido representa el punto de equilibrio matemático donde el incremento de la base reguladora
#     y la disminución de los coeficientes reductores por retrasar la jubilación compensan la pérdida de
#     meses de cobro inmediato.
#
#     AVISO SOBRE EL CONVENIO ESPECIAL:
#     Es fundamental advertir que este cálculo se basa en la cuantía de la pensión. Sin embargo, los meses
#     que se retrase la jubilación anticipada para alcanzar esta cifra conllevan la pérdida del pago del
#     Convenio Especial de la Seguridad Social por parte de la Empresa. El pago de dicho convenio durante
#     esos meses de retraso es un desembolso extra que el trabajador debe asumir, por lo que muy posiblemente,
#     NO compense el incremento de la pensión neta a largo plazo, dependiendo de la esperanza de vida real y
#     de la rentabilidad financiera de ese capital invertido.
#     --------------------------------------------

# %%
# !ls -la /content/prejubilacion/data/outputs/
# Out:
# total 152
# drwxr-xr-x 2 root root   4096 May 17 13:34 .
# drwxr-xr-x 4 root root   4096 May 17 13:34 ..
# -rw-r--r-- 1 root root      0 May 17 13:34 gitkeep.txt
# -rw-r--r-- 1 root root  38121 May 17 13:34 Resumen_Calculo_Jubilacion.xlsx
# -rw-r--r-- 1 root root 103923 May 17 13:36 Resumen_Rentas.xlsx

# %% [markdown]
# ## 10. Copia los datos de salida de vuelta a Google Drive

# %%
# !cp /content/prejubilacion/data/outputs/* /content/drive/MyDrive/data_colab/outputs/

# %% [markdown]
# ## 11. Borra los datos de entrada y salida del proyecto por seguridad

# %%
# !rm /content/prejubilacion/data/inputs/*
# !rm /content/prejubilacion/data/outputs/*
